# %% [markdown]
# # SIMPLE EXPENSE TRACKER

# %% [markdown]
# ## Problem Statement
# Build a command-line expense tracker where users can log their expenses and view their financial status.

# %%
expenses = []

# Add Expense
def add_expense():
    title = input("Enter expense title: ")
    amount = float(input("Enter expense amount: ₹"))

    expense = {
        "title": title,
        "amount": amount
    }

    expenses.append(expense)
    print("Expense added successfully!")

# View Expenses
def view_expenses():
    if not expenses:
        print("No expenses recorded.")
    else:
        print("\n EXPENSE LIST ")

        total = 0

        for index, expense in enumerate(expenses, start=1):
            print(f"{index}. {expense['title']} - ₹{expense['amount']}")
            total += expense['amount']

        print(f"\nTotal Expenses: ₹{total}")

# Delete Expense
def delete_expense():
    view_expenses()

    if expenses:
        choice = int(input("Enter expense number to delete: "))

        if 1 <= choice <= len(expenses):
            removed = expenses.pop(choice - 1)
            print(f"{removed['title']} deleted successfully!")
        else:
            print("Invalid expense number!")

while True:
    print("\n EXPENSE TRACKER ")
    print("1. Add Expense")
    print("2. View Expenses")
    print("3. Delete Expense")
    print("4. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_expense()

    elif choice == "2":
        view_expenses()

    elif choice == "3":
        delete_expense()

    elif choice == "4":
        print("Exiting Expense Tracker")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
#  EXPENSE TRACKER
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Exit
# Enter your choice:  1
# Enter expense title:  TRAVEL
# Enter expense amount: ₹ 7000
# Expense added successfully!
#
#  EXPENSE TRACKER
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Exit
# Enter your choice:  1
# Enter expense title:  FOOD
# Enter expense amount: ₹ 3000
# Expense added successfully!
#
#  EXPENSE TRACKER
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Exit
# Enter your choice:  1
# Enter expense title:  ACCOMMODATION
# Enter expense amount: ₹ 5000
# Expense added successfully!
#
#  EXPENSE TRACKER
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Exit
# Enter your choice:  2
#  EXPENSE LIST
# 1. TRAVEL - ₹7000.0
# 2. FOOD - ₹3000.0
# 3. ACCOMMODATION - ₹5000.0
#
# Total Expenses: ₹15000.0
#
#  EXPENSE TRACKER
# 1. Add Expense
# 2. View Expenses
# 3. Delete Expense
# 4. Exit
# Enter your choice:  3
#  EXPENSE LIST
# 1. TRAVEL - ₹7000.0
# ...

# %% [markdown]
# ## Conclusion
# The Expense Tracker application works through a command-line interface where users can manage their daily expenses. The program stores expense records using a list of dictionaries, where each expense contains a title and amount. Users can add new expenses, view all recorded expenses, delete unwanted expenses, and calculate the total amount spent. Based on the user’s menu selection, the corresponding function is executed and the results are displayed clearly. The application continues running until the user chooses the exit option.
